# %%
import pandas as pd

# %%
csv_wait_state = "Wait_time_by_state.csv"

waitstate_df = pd.read_csv(csv_wait_state, encoding="utf-8")

# %%
waitstate_df.head(50)
# Out:
#          States            Time_Waited  Kidney  Liver  Pancreas  \
# 0       Alabama               All Time   1,099    104         5
# 1       Alabama              < 30 Days      37      2         0
# 2       Alabama        30 to < 90 Days      53     15         0
# 3       Alabama  90 Days to < 6 Months      87     11         0
# 4       Alabama   6 Months to < 1 Year     102     20         0
# 5       Alabama    1 Year to < 2 Years     221     23         2
# 6       Alabama   2 Years to < 3 Years     167     21         2
# 7       Alabama   3 Years to < 5 Years     170      8         0
# 8       Alabama        5 or More Years     264      4         1
# 9       Arizona               All Time   1,397    200         5
# 10      Arizona              < 30 Days      63     30         1
# 11      Arizona        30 to < 90 Days     101     40         0
# 12      Arizona  90 Days to < 6 Months     131     31         0
# 13      Arizona   6 Months to < 1 Year     208     30         0
# ...

# %%
waitstate_df = waitstate_df[waitstate_df.Time_Waited != "All Time"]

# %%
waitstate_df.head(50)
# Out:
#          States            Time_Waited Kidney Liver  Pancreas  \
# 1       Alabama              < 30 Days     37     2         0
# 2       Alabama        30 to < 90 Days     53    15         0
# 3       Alabama  90 Days to < 6 Months     87    11         0
# 4       Alabama   6 Months to < 1 Year    102    20         0
# 5       Alabama    1 Year to < 2 Years    221    23         2
# 6       Alabama   2 Years to < 3 Years    167    21         2
# 7       Alabama   3 Years to < 5 Years    170     8         0
# 8       Alabama        5 or More Years    264     4         1
# 10      Arizona              < 30 Days     63    30         1
# 11      Arizona        30 to < 90 Days    101    40         0
# 12      Arizona  90 Days to < 6 Months    131    31         0
# 13      Arizona   6 Months to < 1 Year    208    30         0
# 14      Arizona    1 Year to < 2 Years    282    37         1
# 15      Arizona   2 Years to < 3 Years    227    12         1
# ...

# %%
waitstate_df.to_csv("Cleaned/wait_time_tableau.csv",encoding="utf-8", index=False, header=True)
