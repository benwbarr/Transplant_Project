# %%
import pandas as pd

# %%
csv_path_GODT = "GODT_downloads.csv"

GODT_df = pd.read_csv(csv_path_GODT, encoding="utf-8")

# %%
GODT_df.head()
# Out:
#     REGION                   COUNTRY  REPORTYEAR  POPULATION  TOTAL Actual DD  \
# 0  America  United States of America        2009       314.7             8022
# 1  America  United States of America        2010       317.6             7943
# 2  America  United States of America        2011       313.1             8126
# 3  America  United States of America        2012       315.8             8143
# 4  America  United States of America        2013       320.1             8269
#
#    Actual DBD  Actual DCD  Total Utilized DD  Utilized DBD  Utilized DCD  ...  \
# 0        7102         920                NaN           NaN           NaN  ...
# 1        7000         943                NaN           NaN           NaN  ...
# 2        7069        1057                NaN           NaN           NaN  ...
# 3        7036        1107                NaN           NaN           NaN  ...
# 4        7062        1207             7795.0        6750.0        1045.0  ...
#
# ...
